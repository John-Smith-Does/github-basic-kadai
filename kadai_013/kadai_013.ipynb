# %%
"""
 課題
 13章で学んだ知識を活かして、商品購入時の消費税を関数で計算するプログラムを作る

 本課題の目標
 Pythonで関数を使ったプログラムが書けるようになること

 課題の内容
 商品購入時の消費税を、関数で計算するプログラムのソースコードを作成して提出してください。
 以下のヒントを参考にして、プログラムを作成してください。

 消費税を加えた計算結果を返す関数を記述する
「結果を返す関数」なので戻り値を使用する

 第1引数に商品の金額、第2引数に消費税（10%）を設定する
 """


# 第1引数に商品の金額、第2引数に消費税を設定する
# 合格基準となっている関数を定義

def total_amount(price, tax_rate):

    # 消費税を計算する 値段*税率=消費税の金額
    tax = price * tax_rate

    # 消費税を加えた合計金額を計算する
    total = price + tax

    # 合計金額を戻り値として返す　合格基準に戻り値で計算結果を返していることとあるため
    return total

# 関数を呼び出し、引数として購入金額と消費税を渡す
price = 1200

# 消費税は10%を設定
tax_rate = 0.1

# total_amount関数を呼び出して、計算結果をresultに代入　定義した関数を呼び出し、使用する
result = total_amount(price,tax_rate)


"""
 作業上の注意事項
 計算結果で小数点が含まれる場合はそのまま表示してください。
 切り捨てや四捨五入などの処理は不要です。

 合格基準
 1 「課題の内容」の仕様通りの関数が定義されている
 2	定義した関数を呼び出し、使用されている
 3	戻り値で計算結果を返していること
 4	引数が適切に設定できていること
 """

# フォーマット文で結果を出力する　計算結果で小数点が含まれる場合はそのまま表示
print(f"合計金額は{result}円です")
# Out:
# 合計金額は1320.0円です
